# %% [markdown]
# # Introduction to geospatial vector data in Python

# %% [markdown]
# ## Importing data

# %%
import pandas as pd

# %% [markdown]
# create and load .csv:

# %%
df=pd.read_csv("locations.csv") #without umlauts #without ß
df
# Out:
#                                  Address:
# 0                  Oberbaumbruecke Berlin
# 1  Strasse der Nationen 62 09111 Chemnitz
# 2                     Gymnasium Gadebusch
# 3               Thurwieserstr 10 Muenchen

# %%
import googlemaps

# %% [markdown]
# ## Generate API Key and request geocode from google

# %% [markdown]
# Instructions you can get from this [video](https://www.youtube.com/watch?v=vTFn9gWEtPA).
#
# [Here](https://console.developers.google.com/apis/dashboard?project=newone-223321&duration=PT1H) you can create your gmaps project.

# %%
gmaps_key=googlemaps.Client(key="AIzaSyBCXFT1G_kluH7e7mc3T9333-jUHK446q4") #request geocode

# %% [markdown]
# extend your dataframe by importing the geocodes:

# %%
df["Latitude"]=None
df["Longitude"]=None

for i in range(0, len(df), 1):
    geocode_result=gmaps_key.geocode(df.iat[i,0])
    try:
        Latitude=geocode_result[0]["geometry"]["location"]["lat"]
        Longitude=geocode_result[0]["geometry"]["location"]["lng"]
        df.iat[i, df.columns.get_loc("Latitude")]=Latitude
        df.iat[i, df.columns.get_loc("Longitude")]=Longitude
    except:
        Latitude=None
        Longitude=None

# %%
df
# Out:
#                                  Address: Latitude Longitude
# 0                  Oberbaumbruecke Berlin  52.5019   13.4459
# 1  Strasse der Nationen 62 09111 Chemnitz  50.8391   12.9275
# 2                     Gymnasium Gadebusch  53.6943   11.1056
# 3               Thurwieserstr 10 Muenchen  48.2112   11.5597

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

img=mpimg.imread('Coord.png')
plt.figure(figsize = (15, 30))

plt.imshow(img)

# %% [markdown]
# ## Importing geospatial data

# %%
# %matplotlib inline

import geopandas

pd.options.display.max_rows=10

# %% [markdown]
# check if the package has been installed to your environment and activate ipykernel for jupyter notebook:

# %%
import sys
'geopandas' in sys.modules
# Out:
# True

# %% [markdown]
# if not: run this command in miniconda shell: **conda install ipykernel --name env** or **python -m ipykernel install**.

# %% [markdown]
# load geo datas from zip-file:

# %%
countries = geopandas.read_file("zip://./ne_110m_admin_0_countries.zip")

# %% [markdown]
# [source of data](https://www.naturalearthdata.com/) from Natural Earth

# %%
countries
# Out:
#     iso_a3                  name      continent     pop_est  gdp_md_est  \
# 0      AFG           Afghanistan           Asia  34124811.0     64080.0
# 1      AGO                Angola         Africa  29310273.0    189000.0
# 2      ALB               Albania         Europe   3047987.0     33900.0
# 3      ARE  United Arab Emirates           Asia   6072475.0    667200.0
# 4      ARG             Argentina  South America  44293293.0    879400.0
# ..     ...                   ...            ...         ...         ...
# 172    VUT               Vanuatu        Oceania    282814.0       723.0
# 173    YEM                 Yemen           Asia  28036829.0     73450.0
# 174    ZAF          South Africa         Africa  54841552.0    739100.0
# 175    ZMB                Zambia         Africa  15972000.0     65170.0
# 176    ZWE              Zimbabwe         Africa  13805084.0     28330.0
#
#                                               geometry
# 0    POLYGON ((61.21081709172574 35.65007233330923,...
# 1    (POLYGON ((23.90415368011818 -11.7222815894063...
# 2    POLYGON ((21.0200403174764 40.84272695572588, ...
# 3    POLYGON ((51.57951867046327 24.24549713795111,...
# 4    (POLYGON ((-66.95992000000001 -54.896810000000...
# ..                                                 ...
# 172  (POLYGON ((167.844876743845 -16.46633310309713...
# 173  POLYGON ((52.00000980002224 19.0000033635161, ...
# 174  POLYGON ((19.89576785653443 -24.76779021576059...
# 175  POLYGON ((23.21504845550606 -17.52311614346598...
# 176  POLYGON ((29.43218834810904 -22.09131275806759...
#
# [177 rows x 6 columns]

# %%
countries.plot(edgecolor='k', facecolor='tab:orange',figsize=(15, 10))

# %%
type(countries)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
countries['pop_est'].mean()
# Out:
# 41712369.84180791

# %%
countries['continent']=='South America'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# Name: continent, Length: 177, dtype: bool

# %%
south_america=countries[countries['continent']=='South America']

# %%
south_america.plot(edgecolor='g', facecolor='yellow',figsize=(15, 10))

# %%
germany=countries[countries['name']=='Germany']

# %%
germany.geometry
# Out:
# 41    POLYGON ((13.59594567226444 48.87717194273715,...
# Name: geometry, dtype: object

# %%
germany.plot(facecolor='xkcd:sky blue',figsize=(15, 10))

# %% [markdown]
# ## Apply own dataframe on geopanda dataframe

# %%
from shapely.geometry import Point, Polygon, LineString #polygons used for regions, lineStrings for rivers etc.

# %%
df['Coordinates']  = list(zip(df.Longitude, df.Latitude))

# %%
df['Coordinates'] = df['Coordinates'].apply(Point)

# %%
gdf = geopandas.GeoDataFrame(df, geometry='Coordinates')
gdf
# Out:
#                                  Address: Latitude Longitude  \
# 0                  Oberbaumbruecke Berlin  52.5019   13.4459
# 1  Strasse der Nationen 62 09111 Chemnitz  50.8391   12.9275
# 2                     Gymnasium Gadebusch  53.6943   11.1056
# 3               Thurwieserstr 10 Muenchen  48.2112   11.5597
#
#                             Coordinates
# 0         POINT (13.4458845 52.5019094)
# 1  POINT (12.9274975 50.83913889999999)
# 2         POINT (11.1056437 53.6942859)
# 3         POINT (11.5597207 48.2111747)

# %% [markdown]
# plot these coordinates with the geopandas dataframe:

# %%
ax = germany.plot(edgecolor='k', facecolor='none', figsize=(15, 10))

gdf.plot(ax=ax, color=['green','red','blue','black'], marker='s')

ax.set(xlabel='Longitude', ylabel='Latitude')
ax.set_title("1st map")
# Out:
# Text(0.5,1,'1st map')

# %% [markdown]
# **you can create your geo dataframe in python as well...**

# %%
df0 = pd.DataFrame( {'City': ['Frankfurt a. Main','Bonn','Dortmund','Kassel'], 'Country': ['Germany','Germany','Germany','Germany'], 'Latitude': [50.11,50.74,51.51,51.31], 'Longitude': [8.68,7.1,7.46,9.48]})

# %%
df0['Coordinates']  = list(zip(df0.Longitude, df0.Latitude))

# %%
df0['Coordinates'] = df0['Coordinates'].apply(Point)

# %%
gdf0 = geopandas.GeoDataFrame(df0, geometry='Coordinates')
gdf0
# Out:
#                 City  Country  Latitude  Longitude         Coordinates
# 0  Frankfurt a. Main  Germany     50.11       8.68  POINT (8.68 50.11)
# 1               Bonn  Germany     50.74       7.10   POINT (7.1 50.74)
# 2           Dortmund  Germany     51.51       7.46  POINT (7.46 51.51)
# 3             Kassel  Germany     51.31       9.48  POINT (9.48 51.31)

# %% [markdown]
# **...and plot them all:**

# %%
ax = germany.plot(edgecolor='k', facecolor='none', figsize=(15, 10))

gdf.plot(ax=ax, color='green')
gdf0.plot(ax=ax, color='red')

ax.set()
# Out:
# []

# %% [markdown]
# ## GeoJSON
# [webpage](http://opendatalab.de/projects/geojson-utilities/)

# %%
BL = geopandas.read_file("bundeslaender_simplify200.geojson")
Sachsen = geopandas.read_file("gemeinden_simplify2001.geojson")
Chemnitz = geopandas.read_file("gemeinden_simplify200.geojson")

# %%
BL
# Out:
#     ADE  GF  BSG  RS AGS        SDV_RS                     GEN  \
# 0     2   4    1  10  10  100410100100                Saarland
# 1     2   4    1  08  08  081110000000       Baden-Württemberg
# 2     2   4    1  05  05  051110000000     Nordrhein-Westfalen
# 3     2   1    1  01  01  010020000000      Schleswig-Holstein
# 4     2   4    1  04  04  040110000000                  Bremen
# ..  ...  ..  ...  ..  ..           ...                     ...
# 29    2   2    1  13  13  130040000000  Mecklenburg-Vorpommern
# 30    2   4    1  16  16  160510000000               Thüringen
# 31    2   1    1  03  03  032410001001           Niedersachsen
# 32    2   4    1  09  09  091620000000                  Bayern
# 33    2   1    1  03  03  032410001001           Niedersachsen
#
#                  BEZ  IBZ BEM  \
# 0               Land   20  --
# 1               Land   20  --
# 2               Land   20  --
# 3               Land   20  --
# 4   Freie Hansestadt   23  --
# ..               ...  ...  ..
# 29              Land   20  --
# 30         Freistaat   21  --
# 31              Land   20  --
# 32         Freistaat   21  --
# 33              Land   20  --
#
#                           ...                         SN_V2 SN_G FK_S3 NUTS  \
# 0                         ...                            00  000     0  DEC
# 1                         ...                            00  000     0  DE1
# 2                         ...                            00  000     0  DEA
# 3                         ...                            00  000     0  DEF
# 4                         ...                            00  000     0  DE5
# ..                        ...                           ...  ...   ...  ...
# 29                        ...                            00  000     0  DE8
# 30                        ...                            00  000     0  DEG
# 31                        ...                            00  000     0  DE9
# 32                        ...                            00  000     0  DE2
# 33                        ...                            00  000     0  DE9
#
#             RS_0     AGS_0         WSK          DEBKG_ID  \
# 0   100000000000  10000000  2009-01-01  DEBKGDL20000E5E3
# 1   080000000000  08000000  1997-01-01  DEBKGDL20000E603
# 2   050000000000  05000000  2009-11-01  DEBKGDL20000E6GR
# 3   010000000000  01000000  2012-02-01  DEBKGDL20000QFG6
# 4   040000000000  04000000  2010-01-01  DEBKGDL20000E0SF
# ..           ...       ...         ...               ...
# 29  130000000000  13000000  2014-11-01  DEBKGDL20000E5I7
# 30  160000000000  16000000  2014-02-01  DEBKGDL20000E09Y
# 31  030000000000  03000000  2015-01-01  DEBKGDL20000QFG5
# 32  090000000000  09000000  2011-07-01  DEBKGDL20000E5HO
# 33  030000000000  03000000  2015-01-01  DEBKGDL200010SHR
#
#                                              destatis  \
# 0   {'population': 989035, 'population_m': 482599,...
# 1   {'population': 10716644, 'population_m': 52842...
# 2   {'population': 17638098, 'population_m': 86060...
# 3   {'population': 2830864, 'population_m': 138145...
# 4   {'population': 661888, 'population_m': 324423,...
# ..                                                ...
# 29  {'population': 1599138, 'population_m': 787945...
# 30  {'population': 2156759, 'population_m': 106293...
# 31  {'population': 7826739, 'population_m': 384608...
# 32  {'population': 12691568, 'population_m': 62499...
# 33  {'population': 7826739, 'population_m': 384608...
#
#                                              geometry
# 0   POLYGON ((7.05907992086318 49.63047962017699, ...
# 1   (POLYGON ((9.651418612909339 49.78055704496921...
# 2   (POLYGON ((8.669988518782317 52.51857063289291...
# 3   (POLYGON ((8.300669237289293 55.06325175383481...
# 4   (POLYGON ((8.504608166710035 53.22891929660262...
# ..                                                ...
# 29  (POLYGON ((13.81862881214692 53.85921831982827...
# 30  POLYGON ((10.78854212880428 51.64152116272316,...
# 31  (POLYGON ((8.21994444028587 53.97841179206505,...
# 32  POLYGON ((10.4539801289261 47.55557895878625, ...
# 33  POLYGON ((7.549846486929489 54.02679661116703,...
#
# [34 rows x 25 columns]

# %%
ax = BL.plot(edgecolor='k', facecolor='none', figsize=(30, 20))
Sachsen.plot(ax=ax, color='yellow')
Chemnitz.plot(ax=ax, color='green')
gdf.plot(ax=ax, color='red')

# %% [markdown]
# ## Clustering

# %% [markdown]
# Clustering population:

# %%
countries.sort_values('pop_est').plot('pop_est', cmap='plasma', figsize=(30, 20), legend=True)

# %% [markdown]
# Clustering GDP:

# %%
countries.sort_values('gdp_md_est').plot('gdp_md_est', cmap='viridis', scheme='equal_interval', k=10, figsize=(30, 20),legend=True)
# Out:
# C:\Users\thoma\Anaconda3\envs\gmaps\lib\site-packages\pysal\__init__.py:65: VisibleDeprecationWarning: PySAL's API will be changed on 2018-12-31. The last release made with this API is version 1.14.4. A preview of the next API version is provided in the `pysalnext` package. The API changes and a guide on how to change imports is provided at https://migrating.pysal.org
#   ), VisibleDeprecationWarning)

# %%
africa=countries[countries['continent']=='Africa']
africa.sort_values('gdp_md_est').plot('gdp_md_est', cmap='viridis',scheme='equal_interval', k=10, figsize=(30, 20),legend=True)
